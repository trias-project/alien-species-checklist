# %%
# %matplotlib inline

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from ggplot import *
sns.set_style("whitegrid")

# %% [markdown]
# ### Vizualisation of species variation in pathways

# %% [markdown]
# 1. From `concatenated.tsv`
# 2. Add `speciesKey` for `acceptedKey` (use GBIF services)
# 3. Group # of unique `speciesKey` by pathway (note: currently ' | ' separated)
# 4. Order pathways in main and sub categories [according to CBD](https://github.com/inbo/alien-species-checklist/issues/62#issuecomment-217879029)
# 5. Create bar chart for number of species.

# %%
concat_data = pd.read_csv("../../data/concatenated.tsv", sep="\t", dtype=object)

# %%
concat_data.columns
# Out:
# Index(['index', 'nameMatchValidation', 'taxonID', 'datasetName',
#        'scientificName', 'verbatimScientificName', 'synonym', 'kingdom',
#        'phylum', 'class', 'order', 'family', 'genus', 'specificEpithet',
#        'infraspecificEpithet', 'vernacularNameEN', 'vernacularNameNL',
#        'vernacularNameFR', 'verbatimInvasionStage', 'invasionStage',
#        'invasionStageCertainty', 'BFIS', 'ISEIA', 'spatialDistribution',
#        'invasiveness', 'verbatimIntroductionPathway', 'introductionPathway',
#        'introductionMode', 'verbatimHabitat', 'habitat', 'verbatimNativeRange',
#        'nativeRange', 'verbatimPresenceBE', 'verbatimPresenceFL',
#        'verbatimPresenceWA', 'verbatimPresenceBR', 'verbatimPresenceBECoast',
#        'verbatimPresenceBPNS', 'verbatimPresenceBEEZ', 'presenceBE',
#        'presenceFL', 'presenceWA', 'presenceBR', 'presenceBECoast',
#        'presenceBPNS', 'presenceBEEZ', 'firstObservationYearBE',
#        'firstObservationYearFL', 'latestObservationYearBE', 'source',
#        'sourceID', 'riskAnalysis', 'publicationStatus', 'notes',
#        'manual_acceptedKey', 'gbifapi_usageKey', 'gbifapi_scientificName',
#        'gbifapi_canonicalName', 'gbifapi_status', 'gbifapi_rank',
#        'gbifapi_matchType', 'gbifapi_confidence', 'gbifapi_acceptedKey',
#        'gbifapi_acceptedScientificName'],
#       dtype='object')

# %% [markdown]
# ### Get speciesKey for acceptedKeys

# %% [markdown]
# Using the Gbif services, we ask for the corresponding `speciesKey` based on the available `acceptedKey`:

# %%
import requests

# %%
def get_species_key(accepted_key):
    """get corresponding species key from acceptedKey-values"""
    r = requests.get("http://api.gbif.org/v1/species/" + str(accepted_key))
    try :
        key = str(r.json()["speciesKey"])
    except:
        key = None
    return key

# %%
concat_data["species_key"] = concat_data.apply(lambda x: get_species_key(x["gbifapi_acceptedKey"]), axis=1)

# %%
concat_data[["species_key", "gbifapi_acceptedKey"]].head()
# Out:
#   species_key gbifapi_acceptedKey
# 0     4287131             4287131
# 1     2402129             2402129
# 2     2402168             2402168
# 3     2340989             2340989
# 4     5851603             5851603

# %% [markdown]
# Check for which these are different:

# %%
concat_data[concat_data["species_key"].astype(float) - concat_data["gbifapi_acceptedKey"].astype(float) > 0.0]
# Out:
#      index            nameMatchValidation taxonID datasetName  \
# 415    415                    ok, SYNONYM     NaN      plants
# 548    548                    ok, SYNONYM     NaN      plants
# 700    700                    ok, SYNONYM     NaN      plants
# 734    734                    ok, SYNONYM     NaN      plants
# 1123  1123                    ok, SYNONYM     NaN      plants
# 1176  1176                             ok     NaN      plants
# 1177  1177                             ok     NaN      plants
# 1178  1178                    ok, SYNONYM     NaN      plants
# 1228  1228                             ok     NaN      plants
# 1362  1362                             ok     NaN      plants
# 1524  1524                    ok, SYNONYM     NaN      plants
# 1665  1665                             ok     NaN      plants
# 1698  1698                             ok     NaN      plants
# 1804  1804                             ok     NaN      plants
# 1805  1805                             ok     NaN      plants
# 1841  1841                             ok     NaN      plants
# 1857  1857                             ok     NaN      plants
# 1874  1874                             ok     NaN      plants
# 1962  1962                    ok, SYNONYM     NaN      plants
# 2047  2047                    ok, SYNONYM     NaN      plants
# 2049  2049                    ok, SYNONYM     NaN      plants
# 2181  2181                    ok, SYNONYM     NaN      plants
# 2226  2226                             ok     NaN      plants
# 2241  2241                             ok     NaN      plants
# 2283  2283                             ok     NaN      plants
# 2287  2287                    ok, SYNONYM     NaN      plants
# 2360  2360                    ok, SYNONYM     NaN      plants
# 2363  2363                    ok, SYNONYM     NaN      plants
# 2364  2364                    ok, SYNONYM     NaN      plants
# 2401  2401                             ok     NaN      plants
# ...    ...                            ...     ...         ...
# 3605  3605                    ok, SYNONYM     NaN       rinse
# 3698  3698                             ok     NaN       rinse
# 3699  3699                             ok     NaN       rinse
# 3952  3952  uncertain rank, single record     NaN       rinse
# 3984  3984  uncertain rank, single record     NaN       rinse
# 4027  4027                    ok, SYNONYM     NaN       rinse
# 4092  4092  uncertain rank, single record     NaN       rinse
# 4094  4094                    ok, SYNONYM     NaN       rinse
# 4255  4255                    ok, SYNONYM     NaN       rinse
# 4308  4308                             ok     NaN       rinse
# 4309  4309                             ok     NaN       rinse
# 4338  4338                          fuzzy     NaN       rinse
# 4403  4403                    ok, SYNONYM     NaN       rinse
# 4985  4985  uncertain rank, single record     NaN       rinse
# 4998  4998                    ok, SYNONYM     NaN       rinse
# 5099  5099                    ok, SYNONYM     NaN       rinse
# 5104  5104                    ok, SYNONYM     NaN       rinse
# 5106  5106                    ok, SYNONYM     NaN       rinse
# 5127  5127                    ok, SYNONYM     NaN       rinse
# 5157  5157                    ok, SYNONYM     NaN       rinse
# 5212  5212                             ok     NaN       rinse
# 5213  5213                             ok     NaN       rinse
# 5234  5234       uncertain rank, DOUBTFUL     NaN       rinse
# 5515  5515  uncertain rank, single record     NaN       rinse
# 5570  5570                    ok, SYNONYM     NaN       rinse
# 5789  5789                    ok, SYNONYM     NaN       rinse
# 5800  5800                             ok     NaN       rinse
# 5890  5890                             ok     NaN       rinse
# 5938  5938                    ok, SYNONYM     NaN       rinse
# 9228  9228                    ok, SYNONYM     NaN       rinse
#
#                                          scientificName  \
# 415   Pastinaca sativa L. subsp. urens (Req. ex Godr...
# 548                           Carduus vivariensis Jord.
# 700   Pilosella bauhinii (Schult. ex Besser) Arv.-Touv.
# 734                    Senecio vernalis Waldst. et Kit.
# 1123                   Jovibarba sobolifera (Sims) Opiz
# 1176  Cyperus longus L. subsp. badius (Desf.) Bonnie...
# 1177                    Cyperus longus L. subsp. longus
# 1178  Cyperus longus L. subsp. tenuiflorus (Rottb.) ...
# 1228  Euphorbia esula L. subsp. tommasiniana (Bertol...
# 1362  Trifolium hybridum L. subsp. elegans (Savi) As...
# 1524                       Callicarpa bodinieri H. Lév.
# 1665  Fraxinus angustifolia Vahl subsp. oxycarpa (Bi...
# 1698  Oenothera fruticosa L. subsp. glauca (Michaux)...
# 1804  Cymbalaria muralis P. Gaertn., B. Mey. et Sche...
# 1805  Cymbalaria muralis P. Gaertn., B. Mey. et Sche...
# 1841  Armeria maritima Willd. subsp. elongata (Hoffm...
# 1857  Aira caryophyllea subsp. plesiantha (Jord.) K....
# 1874  Austrostipa scabra (Lindl.) S.W.L. Jacobs et J...
# 1962             Diplachne parviflora (R. Brown) Benth.
# 2047                             Hordeum glaucum Steud.
# 2049                             Hordeum leporinum Link
# 2181                                 Triticum spelta L.
# 2226  Polygonum aviculare subsp. rurivagum (Jord. ex...
# 2241   Rumex crispus L. subsp. robustus (Rech.) Pestova
# 2283  Cheilanthes viridis (Forssk.) Prantl var. macr...
# 2287                   Aconitum x stoerkianum Reichenb.
# 2360                        Cotoneaster rehderi Pojark.
# 2363              Cotoneaster sternianus (Turrill) Boom
# 2364  Cotoneaster villosulus (Rehd. et E.H. Wilson) ...
# 2401               Prunus domestica L. subsp. domestica
# ...                                                 ...
# 3605                             Cotoneaster villosulus
# 3698                  Cymbalaria muralis subsp. muralis
# 3699                 Cymbalaria muralis subsp. visianii
# 3952                        Erodium aethiopicum pilosum
# 3984                         Escallonia rubra macrantha
# 4027                          Euphorbia X pseudovirgata
# 4092                            Fumaria petteri petteri
# 4094                                 Fumaria x painteri
# 4255                            Helleborus argutifolius
# 4308                     Hordeum murinum subsp. glaucum
# 4309                   Hordeum murinum subsp. leporinum
# 4338                      Hypericum maculatum maculatum
# 4403                                Jovibarba globifera
# 4985                      Paronychia arabica cossoniana
# 4998                      Pastinaca sativa subsp. urens
# 5099                                 Pilosella bauhinii
# 5104                                 Pilosella praealta
# 5106                       Pilosella praealta thaumasia
# 5127                 Plantago lagopus subsp. cylindrica
# 5157                                Polygonum rurivagum
# 5212                  Prunus domestica subsp. domestica
# 5213                    Prunus domestica var. insititia
# 5234              Ptilostemon gnaphaloides gnaphaloides
# 5515                          Scutellaria albida albida
# 5570                                   Senecio vernalis
# 5789                               Stipa scabra falcata
# 5800                    Symphoricarpos albus laevigatus
# 5890                  Trifolium hybridum subsp. elegans
# 5938                                    Triticum spelta
# 9228                         Phymatosorus diversifolius
#
#                                  verbatimScientificName  \
# 415   Pastinaca sativa L. subsp. urens (Req. ex Godr...
# 548                           Carduus vivariensis Jord.
# 700   Pilosella bauhinii (Schult. ex Besser) Arv.-Touv.
# 734                    Senecio vernalis Waldst. et Kit.
# 1123                   Jovibarba sobolifera (Sims) Opiz
# 1176  Cyperus longus L. subsp. badius (Desf.) Bonnie...
# 1177                    Cyperus longus L. subsp. longus
# 1178  Cyperus longus L. subsp. tenuiflorus (Rottb.) ...
# 1228  Euphorbia esula L. subsp. tommasiniana (Bertol...
# 1362  Trifolium hybridum L. subsp. elegans (Savi) As...
# 1524                       Callicarpa bodinieri H. Lév.
# 1665  Fraxinus angustifolia Vahl subsp. oxycarpa (Bi...
# 1698  Oenothera fruticosa L. subsp. glauca (Michaux)...
# 1804  Cymbalaria muralis P. Gaertn., B. Mey. et Sche...
# 1805  Cymbalaria muralis P. Gaertn., B. Mey. et Sche...
# 1841  Armeria maritima Willd. subsp. elongata (Hoffm...
# 1857  Aira caryophyllea subsp. plesiantha (Jord.) K....
# 1874  Austrostipa scabra (Lindl.) S.W.L. Jacobs et J...
# 1962             Diplachne parviflora (R. Brown) Benth.
# 2047                             Hordeum glaucum Steud.
# 2049                             Hordeum leporinum Link
# 2181                                 Triticum spelta L.
# 2226  Polygonum aviculare subsp. rurivagum (Jord. ex...
# 2241  Rumex crispus L. subsp. robustus (Rech.) Pestova
# 2283  Cheilanthes viridis (Forssk.) Prantl var. macr...
# 2287  Aconitum x stoerkianum Reichenb. (A. napellus ...
# 2360                        Cotoneaster rehderi Pojark.
# 2363              Cotoneaster sternianus (Turrill) Boom
# 2364  Cotoneaster villosulus (Rehd. et E.H. Wilson) ...
# 2401               Prunus domestica L. subsp. domestica
# ...                                                 ...
# 3605                             Cotoneaster villosulus
# 3698                         Cymbalaria muralis muralis
# 3699                        Cymbalaria muralis visianii
# 3952                        Erodium aethiopicum pilosum
# 3984                         Escallonia rubra macrantha
# 4027                          Euphorbia X pseudovirgata
# 4092                            Fumaria petteri petteri
# 4094                                 Fumaria x painteri
# 4255                            Helleborus argutifolius
# 4308                            Hordeum murinum glaucum
# 4309                          Hordeum murinum leporinum
# 4338                      Hypericum maculatum maculatum
# 4403                                Jovibarba globifera
# 4985                      Paronychia arabica cossoniana
# 4998                             Pastinaca sativa urens
# 5099                                 Pilosella bauhinii
# 5104                                 Pilosella praealta
# 5106                       Pilosella praealta thaumasia
# 5127                        Plantago lagopus cylindrica
# 5157                                Polygonum rurivagum
# 5212                         Prunus domestica domestica
# 5213                         Prunus domestica insititia
# 5234              Ptilostemon gnaphaloides gnaphaloides
# 5515                          Scutellaria albida albida
# 5570                                   Senecio vernalis
# 5789                               Stipa scabra falcata
# 5800                    Symphoricarpos albus laevigatus
# 5890                         Trifolium hybridum elegans
# 5938                                    Triticum spelta
# 9228                         Phymatosorus diversifolius
#
#                                                 synonym  kingdom  \
# 415                                                 NaN  Plantae
# 548                                                 NaN  Plantae
# 700                Hieracium bauhinii Schult. ex Besser  Plantae
# 734                                                 NaN  Plantae
# 1123                                                NaN  Plantae
# 1176                                                NaN  Plantae
# 1177                                                NaN  Plantae
# 1178                                                NaN  Plantae
# 1228                                                NaN  Plantae
# 1362                                                NaN  Plantae
# 1524                                                NaN  Plantae
# 1665                                                NaN  Plantae
# 1698                          Oenothera tetragona Pursh  Plantae
# 1804                                                NaN  Plantae
# 1805                                                NaN  Plantae
# 1841                                                NaN  Plantae
# 1857  Aira caryophyllea subsp. multiculmis (Dumort.)...  Plantae
# 1874  Stipa scabra Lindl. subsp. falcata (Hughes) Vi...  Plantae
# 1962  Leptochloa parviflora (R. Brown) Verloove et L...  Plantae
# 2047         H. murinum subsp. glaucum (Steud.) Tzvelev  Plantae
# 2049         H. murinum subsp. leporinum (Link) Arcang.  Plantae
# 2181                                                NaN  Plantae
# 2226                                                NaN  Plantae
# 2241                                                NaN  Plantae
# 2283                                                NaN  Plantae
# 2287                                                NaN  Plantae
# 2360  Cotoneaster bullatus Bois var. macrophyllus Re...  Plantae
# 2363                                                NaN  Plantae
# 2364                                                NaN  Plantae
# 2401                                                NaN  Plantae
# ...                                                 ...      ...
# 3605                                                NaN  Plantae
# 3698                                                NaN  Plantae
# 3699                                                NaN  Plantae
# 3952                                                NaN  Plantae
# 3984                                                NaN  Plantae
# 4027                                                NaN  Plantae
# 4092                                                NaN  Plantae
# 4094                                                NaN  Plantae
# 4255                                                NaN  Plantae
# 4308                                                NaN  Plantae
# 4309                                                NaN  Plantae
# 4338                                                NaN  Plantae
# 4403                                                NaN  Plantae
# 4985                                                NaN  Plantae
# 4998                                                NaN  Plantae
# 5099                                                NaN  Plantae
# 5104                                                NaN  Plantae
# 5106                                                NaN  Plantae
# 5127                                                NaN  Plantae
# 5157                                                NaN  Plantae
# 5212                                                NaN  Plantae
# 5213                                                NaN  Plantae
# 5234                                                NaN  Plantae
# 5515                                                NaN  Plantae
# 5570                                                NaN  Plantae
# 5789                                                NaN  Plantae
# 5800                                                NaN  Plantae
# 5890                                                NaN  Plantae
# 5938                                                NaN  Plantae
# 9228                                                NaN  Plantae
#
#             phylum             class     ...     gbifapi_usageKey  \
# 415            NaN               NaN     ...              7466434
# 548            NaN               NaN     ...              4210773
# 700            NaN               NaN     ...              6064433
# 734            NaN               NaN     ...              6063730
# 1123           NaN               NaN     ...              7334511
# 1176           NaN               NaN     ...              7421129
# 1177           NaN               NaN     ...              7070211
# 1178           NaN               NaN     ...              2716588
# 1228           NaN               NaN     ...              3064269
# 1362           NaN               NaN     ...              5359402
# 1524           NaN               NaN     ...              7309012
# 1665           NaN               NaN     ...              6432925
# 1698           NaN               NaN     ...              3666449
# 1804           NaN               NaN     ...              7331861
# 1805           NaN               NaN     ...              5559841
# 1841           NaN               NaN     ...              4090836
# 1857           NaN               NaN     ...              6084799
# 1874           NaN               NaN     ...              4104890
# 1962           NaN               NaN     ...              4122787
# 2047           NaN               NaN     ...              4116483
# 2049           NaN               NaN     ...              4115652
# 2181           NaN               NaN     ...              2706402
# 2226           NaN               NaN     ...              5652131
# 2241           NaN               NaN     ...              4035024
# 2283           NaN               NaN     ...              3746867
# 2287           NaN               NaN     ...              3920712
# 2360           NaN               NaN     ...              3026160
# 2363           NaN               NaN     ...              3026154
# 2364           NaN               NaN     ...              3025564
# 2401           NaN               NaN     ...              6369140
# ...            ...               ...     ...                  ...
# 3605  Angiospermae  Eudicotyledoneae     ...              3025564
# 3698  Angiospermae               NaN     ...              7331861
# 3699  Angiospermae               NaN     ...              5559838
# 3952  Angiospermae               NaN     ...              3828942
# 3984  Angiospermae               NaN     ...              3932661
# 4027  Angiospermae  Eudicotyledoneae     ...              3064268
# 4092  Angiospermae               NaN     ...              7315206
# 4094  Angiospermae               NaN     ...              5531906
# 4255  Angiospermae               NaN     ...              3924221
# 4308  Angiospermae               NaN     ...              4115425
# 4309  Angiospermae               NaN     ...              4270548
# 4338  Angiospermae               NaN     ...              3714979
# 4403  Angiospermae               NaN     ...              8178408
# 4985  Angiospermae               NaN     ...              7512071
# 4998  Angiospermae               NaN     ...              7466434
# 5099  Angiospermae               NaN     ...              6064433
# 5104  Angiospermae               NaN     ...              7597101
# 5106  Angiospermae               NaN     ...              4230859
# 5127  Angiospermae               NaN     ...              4156079
# 5157  Angiospermae               NaN     ...              5334432
# 5212  Angiospermae  Eudicotyledoneae     ...              6369140
# 5213  Angiospermae  Eudicotyledoneae     ...              7409013
# 5234  Angiospermae               NaN     ...              6076180
# 5515  Angiospermae               NaN     ...              7309074
# 5570  Angiospermae  Eudicotyledoneae     ...              6063730
# 5789  Angiospermae               NaN     ...              4133554
# 5800  Angiospermae  Eudicotyledoneae     ...              6369607
# 5890  Angiospermae               NaN     ...              5359402
# 5938  Angiospermae               NaN     ...              2706402
# 9228  Pteridophyta      Pteridopsida     ...              4025486
#
#                                  gbifapi_scientificName  \
# 415   Pastinaca sativa subsp. urens (Req. ex Godr.) ...
# 548                           Carduus vivariensis Jord.
# 700       Pilosella bauhinii (Schult.) Arv.-Touv., 1881
# 734                     Senecio vernalis Waldst. & Kit.
# 1123                Jovibarba sobolifera (J. Sims) Opiz
# 1176  Cyperus longus subsp. badius (Desf.) Bonnier &...
# 1177                       Cyperus longus subsp. longus
# 1178    Cyperus longus subsp. tenuiflorus (Rottb.) Kük.
# 1228  Euphorbia esula subsp. tommasiniana (Bertol.) ...
# 1362  Trifolium hybridum subsp. elegans (Savi)Asch. ...
# 1524                        Callicarpa bodinieri H.Lév.
# 1665  Fraxinus angustifolia subsp. oxycarpa (M.Bieb....
# 1698  Oenothera fruticosa subsp. glauca (Michx.) Str...
# 1804                  Cymbalaria muralis subsp. muralis
# 1805  Cymbalaria muralis subsp. pubescens (C. Presl)...
# 1841  Armeria maritima subsp. elongata (Hoffm.) Bonnier
# 1857  Aira caryophyllea subsp. plesiantha (Jord.) K....
# 1874  Austrostipa scabra subsp. falcata (Hughes) S.W...
# 1962                Diplachne parviflora (R.Br.) Benth.
# 2047                             Hordeum glaucum Steud.
# 2049                             Hordeum leporinum Link
# 2181                                 Triticum spelta L.
# 2226  Polygonum aviculare subsp. rurivagum (Boreau) ...
# 2241  Rumex crispus subsp. robustus (Rech.) L.O. Pes...
# 2283  Cheilanthes viridis var. macrophylla (Kze.) Sc...
# 2287                         Aconitum stoerkianum Rchb.
# 2360                         Cotoneaster rehderi Pojark
# 2363              Cotoneaster sternianus (Turrill) Boom
# 2364  Cotoneaster villosulus (Rehder & E.H. Wilson) ...
# 2401                  Prunus domestica subsp. domestica
# ...                                                 ...
# 3605  Cotoneaster villosulus (Rehder & E.H. Wilson) ...
# 3698                  Cymbalaria muralis subsp. muralis
# 3699      Cymbalaria muralis subsp. visianii D. A. Webb
# 3952  Erodium aethiopicum subsp. pilosum (Thuill. ex...
# 3984  Escallonia rubra var. macrantha (Hook. & Arn.)...
# 4027               Euphorbia ×pseudovirgata (Schur) Soo
# 4092                     Fumaria petteri subsp. petteri
# 4094                           Fumaria painteri Pugsley
# 4255                       Helleborus argutifolius Viv.
# 4308    Hordeum murinum subsp. glaucum (Steud.) Tzvelev
# 4309    Hordeum murinum subsp. leporinum (Link) Arcang.
# 4338  Hypericum maculatum subsp. immaculatum (Murb.)...
# 4403                Jovibarba globifera (L.) J. Parnell
# 4985  Paronychia arabica subsp. cossoniana (J. Gay e...
# 4998  Pastinaca sativa subsp. urens (Req. ex Godr.) ...
# 5099      Pilosella bauhinii (Schult.) Arv.-Touv., 1881
# 5104  Pilosella praealta (Vill. ex Gochnat) F.W.Schu...
# 5106  Pilosella praealta F.W.Schultz & Sch.Bip. subs...
# 5127  Plantago lagopus subsp. cylindrica (Boiss.) Fr...
# 5157                         Polygonum rurivagum Boreau
# 5212                  Prunus domestica subsp. domestica
# 5213  Prunus domestica subsp. insititia (L.) Bonnier...
# 5234       Ptilostemon gnaphaloides subsp. gnaphaloides
# 5515                   Scutellaria albida subsp. albida
# 5570                    Senecio vernalis Waldst. & Kit.
# 5789  Stipa scabra subsp. falcata (Hughes) Vickery, ...
# 5800  Symphoricarpos albus var. laevigatus (Fern.) B...
# 5890  Trifolium hybridum subsp. elegans (Savi)Asch. ...
# 5938                                 Triticum spelta L.
# 9228    Phymatosorus diversifolius (Willd.) Pichi-Serm.
#
#                       gbifapi_canonicalName gbifapi_status gbifapi_rank  \
# 415                  Pastinaca sativa urens        SYNONYM   SUBSPECIES
# 548                     Carduus vivariensis        SYNONYM      SPECIES
# 700                      Pilosella bauhinii        SYNONYM      SPECIES
# 734                        Senecio vernalis        SYNONYM      SPECIES
# 1123                   Jovibarba sobolifera        SYNONYM      SPECIES
# 1176                  Cyperus longus badius       ACCEPTED   SUBSPECIES
# 1177                  Cyperus longus longus       ACCEPTED   SUBSPECIES
# 1178             Cyperus longus tenuiflorus        SYNONYM   SUBSPECIES
# 1228           Euphorbia esula tommasiniana       ACCEPTED   SUBSPECIES
# 1362             Trifolium hybridum elegans       ACCEPTED   SUBSPECIES
# 1524                   Callicarpa bodinieri        SYNONYM      SPECIES
# 1665         Fraxinus angustifolia oxycarpa       ACCEPTED   SUBSPECIES
# 1698             Oenothera fruticosa glauca       ACCEPTED   SUBSPECIES
# 1804             Cymbalaria muralis muralis       ACCEPTED   SUBSPECIES
# 1805           Cymbalaria muralis pubescens       ACCEPTED   SUBSPECIES
# 1841              Armeria maritima elongata       ACCEPTED   SUBSPECIES
# 1857           Aira caryophyllea plesiantha       ACCEPTED   SUBSPECIES
# 1874             Austrostipa scabra falcata       ACCEPTED   SUBSPECIES
# 1962                   Diplachne parviflora        SYNONYM      SPECIES
# 2047                        Hordeum glaucum        SYNONYM      SPECIES
# 2049                      Hordeum leporinum        SYNONYM      SPECIES
# 2181                        Triticum spelta        SYNONYM      SPECIES
# 2226          Polygonum aviculare rurivagum       ACCEPTED   SUBSPECIES
# 2241                 Rumex crispus robustus       ACCEPTED   SUBSPECIES
# 2283        Cheilanthes viridis macrophylla       ACCEPTED      VARIETY
# 2287                   Aconitum stoerkianum        SYNONYM      SPECIES
# 2360                    Cotoneaster rehderi        SYNONYM      SPECIES
# 2363                 Cotoneaster sternianus        SYNONYM      SPECIES
# 2364                 Cotoneaster villosulus        SYNONYM      SPECIES
# 2401             Prunus domestica domestica       ACCEPTED   SUBSPECIES
# ...                                     ...            ...          ...
# 3605                 Cotoneaster villosulus        SYNONYM      SPECIES
# 3698             Cymbalaria muralis muralis       ACCEPTED   SUBSPECIES
# 3699            Cymbalaria muralis visianii       ACCEPTED   SUBSPECIES
# 3952            Erodium aethiopicum pilosum       ACCEPTED   SUBSPECIES
# 3984             Escallonia rubra macrantha       ACCEPTED      VARIETY
# 4027                Euphorbia pseudovirgata        SYNONYM      SPECIES
# 4092                Fumaria petteri petteri       ACCEPTED   SUBSPECIES
# 4094                       Fumaria painteri        SYNONYM      SPECIES
# 4255                Helleborus argutifolius        SYNONYM      SPECIES
# 4308                Hordeum murinum glaucum       ACCEPTED   SUBSPECIES
# 4309              Hordeum murinum leporinum       ACCEPTED   SUBSPECIES
# 4338        Hypericum maculatum immaculatum       ACCEPTED   SUBSPECIES
# 4403                    Jovibarba globifera        SYNONYM      SPECIES
# 4985          Paronychia arabica cossoniana       ACCEPTED   SUBSPECIES
# 4998                 Pastinaca sativa urens        SYNONYM   SUBSPECIES
# 5099                     Pilosella bauhinii        SYNONYM      SPECIES
# 5104                     Pilosella praealta        SYNONYM      SPECIES
# 5106           Pilosella praealta thaumasia        SYNONYM   SUBSPECIES
# 5127            Plantago lagopus cylindrica        SYNONYM   SUBSPECIES
# 5157                    Polygonum rurivagum        SYNONYM      SPECIES
# 5212             Prunus domestica domestica       ACCEPTED   SUBSPECIES
# 5213             Prunus domestica insititia       ACCEPTED   SUBSPECIES
# 5234  Ptilostemon gnaphaloides gnaphaloides       DOUBTFUL   SUBSPECIES
# 5515              Scutellaria albida albida       ACCEPTED   SUBSPECIES
# 5570                       Senecio vernalis        SYNONYM      SPECIES
# 5789                   Stipa scabra falcata        SYNONYM   SUBSPECIES
# 5800        Symphoricarpos albus laevigatus       ACCEPTED      VARIETY
# 5890             Trifolium hybridum elegans       ACCEPTED   SUBSPECIES
# 5938                        Triticum spelta        SYNONYM      SPECIES
# 9228             Phymatosorus diversifolius        SYNONYM      SPECIES
#
#      gbifapi_matchType gbifapi_confidence gbifapi_acceptedKey  \
# 415              EXACT                100             7224157
# 548              EXACT                100             6076849
# 700              EXACT                100             8111836
# 734              EXACT                 99             4228701
# 1123             EXACT                100             7334391
# 1176             EXACT                 99             7421129
# 1177             EXACT                100             7070211
# 1178             EXACT                 98             7070211
# 1228             EXACT                 99             3064269
# 1362             EXACT                 99             5359402
# 1524             EXACT                100             3896440
# 1665             EXACT                 99             6432925
# 1698             EXACT                 99             3666449
# 1804             EXACT                 99             7331861
# 1805             EXACT                100             5559841
# 1841             EXACT                 99             4090836
# 1857             EXACT                100             6084799
# 1874             EXACT                100             4104890
# 1962             EXACT                100             7998563
# 2047             EXACT                100             4115425
# 2049             EXACT                100             4270548
# 2181             EXACT                100             2706403
# 2226             EXACT                 99             5652131
# 2241             EXACT                 99             4035024
# 2283             EXACT                100             3746867
# 2287             EXACT                100             3930757
# 2360             EXACT                100             3026161
# 2363             EXACT                100             3026155
# 2364             EXACT                100             3025565
# 2401             EXACT                 99             6369140
# ...                ...                ...                 ...
# 3605             EXACT                100             3025565
# 3698             EXACT                 99             7331861
# 3699             EXACT                 99             5559838
# 3952             EXACT                100             3828942
# 3984             EXACT                100             3932661
# 4027             EXACT                 98             3064262
# 4092             EXACT                100             7315206
# 4094             EXACT                100             5532015
# 4255             EXACT                100             7493700
# 4308             EXACT                100             4115425
# 4309             EXACT                 99             4270548
# 4338             FUZZY                 99             3714979
# 4403             EXACT                 99             7334391
# 4985             EXACT                 99             7512071
# 4998             EXACT                100             7224157
# 5099             EXACT                100             8111836
# 5104             EXACT                 99             4230951
# 5106             EXACT                100             8111836
# 5127             EXACT                 98             7303120
# 5157             EXACT                100             5652131
# 5212             EXACT                 99             6369140
# 5213             EXACT                 99             7409013
# 5234             EXACT                100             6076180
# 5515             EXACT                100             7309074
# 5570             EXACT                 99             4228701
# 5789             EXACT                100             4104890
# 5800             EXACT                 99             6369607
# 5890             EXACT                 99             5359402
# 5938             EXACT                100             2706403
# 9228             EXACT                100             4025284
#
#                          gbifapi_acceptedScientificName species_key
# 415                      Pastinaca sativa subsp. sativa     8262702
# 548   Carduus nigrescens subsp. vivariensis (Jord.) ...     7984807
# 700   Pilosella piloselloides subsp. bauhini (Schult...     8288930
# 734   Senecio leucanthemifolius subsp. vernalis (Wal...     7624085
# 1123           Sempervivum globiferum subsp. globiferum     8091002
# 1176  Cyperus longus subsp. badius (Desf.) Bonnier &...     8243603
# 1177                       Cyperus longus subsp. longus     8243603
# 1178                       Cyperus longus subsp. longus     8243603
# 1228  Euphorbia esula subsp. tommasiniana (Bertol.) ...     8203538
# 1362  Trifolium hybridum subsp. elegans (Savi)Asch. ...     6109535
# 1524  Premna puberula var. bodinieri (H.Lév.) C.Y.Wu...     7308474
# 1665  Fraxinus angustifolia subsp. oxycarpa (M.Bieb....     7325877
# 1698  Oenothera fruticosa subsp. glauca (Michx.) Str...     7884360
# 1804                  Cymbalaria muralis subsp. muralis     8200663
# 1805  Cymbalaria muralis subsp. pubescens (C. Presl)...     8200663
# 1841  Armeria maritima subsp. elongata (Hoffm.) Bonnier     7700420
# 1857  Aira caryophyllea subsp. plesiantha (Jord.) K....     7747216
# 1874  Austrostipa scabra subsp. falcata (Hughes) S.W...     4104891
# 1962                       Diplachne fusca subsp. fusca     8010581
# 2047    Hordeum murinum subsp. glaucum (Steud.) Tzvelev     7886346
# 2049    Hordeum murinum subsp. leporinum (Link) Arcang.     7886346
# 2181        Triticum aestivum subsp. spelta (L.) Thell.     7795888
# 2226  Polygonum aviculare subsp. rurivagum (Boreau) ...     7821030
# 2241  Rumex crispus subsp. robustus (Rech.) L.O. Pes...     8195144
# 2283  Cheilanthes viridis var. macrophylla (Kze.) Sc...     7173446
# 2287  Aconitum variegatum subsp. paniculatum (Arcang...     8090449
# 2360  Cotoneaster bullatus var. macrophyllus Rehder ...     3026294
# 2363     Cotoneaster franchetii var. sternianus Turrill     3026162
# 2364  Cotoneaster acutifolius var. villosulus Rehd. ...     3025770
# 2401                  Prunus domestica subsp. domestica     7931731
# ...                                                 ...         ...
# 3605  Cotoneaster acutifolius var. villosulus Rehd. ...     3025770
# 3698                  Cymbalaria muralis subsp. muralis     8200663
# 3699      Cymbalaria muralis subsp. visianii D. A. Webb     8200663
# 3952  Erodium aethiopicum subsp. pilosum (Thuill. ex...     6366105
# 3984  Escallonia rubra var. macrantha (Hook. & Arn.)...     8405971
# 4027  Euphorbia esula nothosubsp. pseudovirgata (Sch...     8203538
# 4092                     Fumaria petteri subsp. petteri     8165465
# 4094                     Fumaria muralis subsp. muralis     7315286
# 4255  Helleborus lividus subsp. corsicus (Briq.) P. ...     7769371
# 4308    Hordeum murinum subsp. glaucum (Steud.) Tzvelev     7886346
# 4309    Hordeum murinum subsp. leporinum (Link) Arcang.     7886346
# 4338  Hypericum maculatum subsp. immaculatum (Murb.)...     7965788
# 4403           Sempervivum globiferum subsp. globiferum     8091002
# 4985  Paronychia arabica subsp. cossoniana (J. Gay e...     7750274
# 4998                     Pastinaca sativa subsp. sativa     8262702
# 5099  Pilosella piloselloides subsp. bauhini (Schult...     8288930
# 5104  Pilosella piloselloides subsp. praealta (Gochn...     8288930
# 5106  Pilosella piloselloides subsp. bauhini (Schult...     8288930
# 5127                    Plantago lagopus subsp. lagopus     8022932
# 5157  Polygonum aviculare subsp. rurivagum (Boreau) ...     7821030
# 5212                  Prunus domestica subsp. domestica     7931731
# 5213  Prunus domestica subsp. insititia (L.) Bonnier...     7931731
# 5234       Ptilostemon gnaphaloides subsp. gnaphaloides     8279446
# 5515                   Scutellaria albida subsp. albida     7428462
# 5570  Senecio leucanthemifolius subsp. vernalis (Wal...     7624085
# 5789  Austrostipa scabra subsp. falcata (Hughes) S.W...     4104891
# 5800  Symphoricarpos albus var. laevigatus (Fern.) B...     7523753
# 5890  Trifolium hybridum subsp. elegans (Savi)Asch. ...     6109535
# 5938        Triticum aestivum subsp. spelta (L.) Thell.     7795888
# 9228          Phymatosorus pustulatus subsp. pustulatus     7289996
#
# [68 rows x 65 columns]

# %% [markdown]
# ### Split pathway based on |

# %%
concat_data.groupby(['introductionPathway']).first().head()
# Out:
#                                                    index nameMatchValidation  \
# introductionPathway
# contaminant > contaminant nursery material           412                  ok
# contaminant > contaminant nursery material | st...   645         ok, SYNONYM
# contaminant > contaminant on animals (except pa...     6                  ok
# contaminant > contaminant on animals (except pa...   317         ok, SYNONYM
# contaminant > contaminant on animals (except pa...  1055                  ok
#
#                                                    taxonID datasetName  \
# introductionPathway
# contaminant > contaminant nursery material             NaN      plants
# contaminant > contaminant nursery material | st...     NaN      plants
# contaminant > contaminant on animals (except pa...     NaN      fishes
# contaminant > contaminant on animals (except pa...     NaN      plants
# contaminant > contaminant on animals (except pa...     NaN      plants
#
#                                                                               scientificName  \
# introductionPathway
# contaminant > contaminant nursery material                        Oenanthe pimpinelloides L.
# contaminant > contaminant nursery material | st...  Gamochaeta pensylvanica (Willd.) Cabrera
# contaminant > contaminant on animals (except pa...                         Carassius gibelio
# contaminant > contaminant on animals (except pa...                        Blitum virgatum L.
# contaminant > contaminant on animals (except pa...           Polycarpon tetraphyllum (L.) L.
#
#                                                                       verbatimScientificName  \
# introductionPathway
# contaminant > contaminant nursery material                        Oenanthe pimpinelloides L.
# contaminant > contaminant nursery material | st...  Gamochaeta pensylvanica (Willd.) Cabrera
# contaminant > contaminant on animals (except pa...                         Carassius gibelio
# contaminant > contaminant on animals (except pa...                        Blitum virgatum L.
# contaminant > contaminant on animals (except pa...           Polycarpon tetraphyllum (L.) L.
#
#                                                                                               synonym  \
# introductionPathway
# contaminant > contaminant nursery material          C. flexuosa With. subsp. debilis (D. Don) O.E....
# contaminant > contaminant nursery material | st...                    Gnaphalium pensylvanicum Willd.
# contaminant > contaminant on animals (except pa...               Aptenia cordifolia (L. f.) Schwantes
# contaminant > contaminant on animals (except pa...                      Chenopodium foliosum Aschers.
# contaminant > contaminant on animals (except pa...                                                NaN
#
#                                                      kingdom phylum class  \
# introductionPathway
# contaminant > contaminant nursery material           Plantae    NaN   NaN
# contaminant > contaminant nursery material | st...   Plantae    NaN   NaN
# contaminant > contaminant on animals (except pa...  Animalia    NaN   NaN
# contaminant > contaminant on animals (except pa...   Plantae    NaN   NaN
# contaminant > contaminant on animals (except pa...   Plantae    NaN   NaN
#
#                                                        ...      \
# introductionPathway                                    ...
# contaminant > contaminant nursery material             ...
# contaminant > contaminant nursery material | st...     ...
# contaminant > contaminant on animals (except pa...     ...
# contaminant > contaminant on animals (except pa...     ...
# contaminant > contaminant on animals (except pa...     ...
#
#                                                    gbifapi_usageKey  \
# introductionPathway
# contaminant > contaminant nursery material                  5371889
# contaminant > contaminant nursery material | st...          3103082
# contaminant > contaminant on animals (except pa...          2366634
# contaminant > contaminant on animals (except pa...          5383969
# contaminant > contaminant on animals (except pa...          3085381
#
#                                                                       gbifapi_scientificName  \
# introductionPathway
# contaminant > contaminant nursery material                        Oenanthe pimpinelloides L.
# contaminant > contaminant nursery material | st...  Gamochaeta pensylvanica (Willd.) Cabrera
# contaminant > contaminant on animals (except pa...           Carassius gibelio (Bloch, 1782)
# contaminant > contaminant on animals (except pa...                        Blitum virgatum L.
# contaminant > contaminant on animals (except pa...           Polycarpon tetraphyllum (L.) L.
#
#                                                       gbifapi_canonicalName  \
# introductionPathway
# contaminant > contaminant nursery material          Oenanthe pimpinelloides
# contaminant > contaminant nursery material | st...  Gamochaeta pensylvanica
# contaminant > contaminant on animals (except pa...        Carassius gibelio
# contaminant > contaminant on animals (except pa...          Blitum virgatum
# contaminant > contaminant on animals (except pa...  Polycarpon tetraphyllum
#
#                                                    gbifapi_status  \
# introductionPathway
# contaminant > contaminant nursery material               ACCEPTED
# contaminant > contaminant nursery material | st...        SYNONYM
# contaminant > contaminant on animals (except pa...       ACCEPTED
# contaminant > contaminant on animals (except pa...        SYNONYM
# contaminant > contaminant on animals (except pa...       ACCEPTED
#
#                                                    gbifapi_rank  \
# introductionPathway
# contaminant > contaminant nursery material              SPECIES
# contaminant > contaminant nursery material | st...      SPECIES
# contaminant > contaminant on animals (except pa...      SPECIES
# contaminant > contaminant on animals (except pa...      SPECIES
# contaminant > contaminant on animals (except pa...      SPECIES
#
#                                                    gbifapi_matchType  \
# introductionPathway
# contaminant > contaminant nursery material                     EXACT
# contaminant > contaminant nursery material | st...             EXACT
# contaminant > contaminant on animals (except pa...             EXACT
# contaminant > contaminant on animals (except pa...             EXACT
# contaminant > contaminant on animals (except pa...             EXACT
#
#                                                    gbifapi_confidence  \
# introductionPathway
# contaminant > contaminant nursery material                         99
# contaminant > contaminant nursery material | st...                100
# contaminant > contaminant on animals (except pa...                100
# contaminant > contaminant on animals (except pa...                100
# contaminant > contaminant on animals (except pa...                100
#
#                                                    gbifapi_acceptedKey  \
# introductionPathway
# contaminant > contaminant nursery material                     5371889
# contaminant > contaminant nursery material | st...             5390730
# contaminant > contaminant on animals (except pa...             2366634
# contaminant > contaminant on animals (except pa...             3083844
# contaminant > contaminant on animals (except pa...             3085381
#
#                                                      gbifapi_acceptedScientificName  \
# introductionPathway
# contaminant > contaminant nursery material               Oenanthe pimpinelloides L.
# contaminant > contaminant nursery material | st...  Gnaphalium pensylvanicum Willd.
# contaminant > contaminant on animals (except pa...  Carassius gibelio (Bloch, 1782)
# contaminant > contaminant on animals (except pa...       Chenopodium foliosum Asch.
# contaminant > contaminant on animals (except pa...  Polycarpon tetraphyllum (L.) L.
#
#                                                    species_key
# introductionPathway
# contaminant > contaminant nursery material             5371889
# contaminant > contaminant nursery material | st...     5390730
# contaminant > contaminant on animals (except pa...     2366634
# contaminant > contaminant on animals (except pa...     3083844
# contaminant > contaminant on animals (except pa...     3085381
#
# [5 rows x 64 columns]

# %%
def split_double_field_entry(df, keyword="|", column='introductionPathway'):
    """split on keyword in column for an enumeration and create extra record
    """
    s = df[column].str.lower().str.split(keyword).apply(pd.Series, 1).stack()
    s.index = s.index.droplevel(-1)
    s.name = column
    del df[column]
    return df.join(s)

# %%
pathway_uitvouwen = split_double_field_entry(concat_data, keyword="|", column='introductionPathway')

# %%
pathway_uitvouwen["introductionPathway"] = pathway_uitvouwen["introductionPathway"].str.strip()

# %%
unique_species = pathway_uitvouwen.groupby("introductionPathway").species_key.nunique()

# %%
unique_species = pd.DataFrame(unique_species).reset_index()

# %%
unique_species["category"] = unique_species["introductionPathway"].str.split(">").str.get(0).str.strip()
unique_species["subcategory"] = unique_species["introductionPathway"].str.split(">").str.get(1).str.strip()
unique_species = unique_species.rename(columns={"species_key": "count_species_key"})

# %%
unique_species.to_csv("fig_base.tsv", sep="\t")

# %%
unique_species = pd.read_csv("fig_base.csv")

# %%
unique_species = unique_species.drop("Unnamed: 0", axis=1)

# %%
unique_species.to_csv("fig_base.tsv", sep="\t")

# %%
species_category = unique_species.groupby("category").agg({"count_species_key":sum})
species_category.plot(kind="barh", logx=False)
plt.tight_layout()
plt.savefig("category_count.png")

# %%
unique_species[["count_species_key", "introductionPathway"]].set_index("introductionPathway").plot(kind="barh", figsize=(12, 12))
plt.tight_layout()
plt.savefig("subcategory_count.png")

# %%
unique_species['subcategory'] = unique_species['subcategory'].astype(str)
unique_species['category'] = unique_species['category'].astype(object)
unique_species["subcategory"] = unique_species["subcategory"].replace("nan", "unknown")

# %%
ggplot(aes(x='subcategory', weight='count_species_key'), data=unique_species) +\
        geom_bar()
# Out:
# <ggplot: (-9223363307206403931)>

# %%
unique_species
# Out:
#     Unnamed: 0                                introductionPathway  \
# 0            0         contaminant > contaminant nursery material
# 1            1  contaminant > contaminant on animals (except p...
# 2            2  contaminant > contaminant on plants (except pa...
# 3            3                     contaminant > seed contaminant
# 4            4                         contaminant > timber trade
# 5            5  contaminant > transportation of habitat materi...
# 6            6    corridor > interconnected waterways/basins/seas
# 7            7             corridor > to be determined by experts
# 8            8  escape > agriculture (including biofuel feedst...
# 9            9                 escape > aquaculture / mariculture
# 10          10  escape > forestry (including afforestation or ...
# 11          11                                 escape > fur farms
# 12          12                              escape > horticulture
# 13          13                   escape > live food and live bait
# 14          14  escape > ornamental purpose other than horticu...
# 15          15  escape > pet/aquarium/terrarium species (inclu...
# 16          16               escape > to be determined by experts
# 17          17                       release > biological control
# 18          18  release > fishery in the wild (including game ...
# 19          19              release > to be determined by experts
# 20          20                                           stowaway
# 21          21               stowaway > angling/fishing equipment
# 22          22                stowaway > other means of transport
# 23          23  stowaway > people and their luggage/equipment ...
# 24          24                 stowaway > ship/boat ballast water
# 25          25             stowaway > to be determined by experts
# 26          26                        to be determined by experts
# 27          27  unaided > natural dispersal across borders of ...
# 28          28                                            unknown
#
#     count_species_key                     category  \
# 0                  16                  contaminant
# 1                 517                  contaminant
# 2                   3                  contaminant
# 3                 501                  contaminant
# 4                   7                  contaminant
# 5                  51                  contaminant
# 6                  10                     corridor
# 7                   9                     corridor
# 8                  73                       escape
# 9                  18                       escape
# 10                  1                       escape
# 11                  4                       escape
# 12                905                       escape
# 13                 25                       escape
# 14                  3                       escape
# 15                 20                       escape
# 16                 66                       escape
# 17                  4                      release
# 18                  4                      release
# 19                  8                      release
# 20                 10                     stowaway
# 21                  1                     stowaway
# 22                  1                     stowaway
# 23                  3                     stowaway
# 24                  2                     stowaway
# 25                 48                     stowaway
# 26               6004  to be determined by experts
# 27                  3                      unaided
# 28                273                      unknown
#
#                                           subcategory
# 0                        contaminant nursery material
# 1   contaminant on animals (except parasites, spec...
# 2   contaminant on plants (except parasites, speci...
# 3                                    seed contaminant
# 4                                        timber trade
# 5   transportation of habitat material (soil, vege...
# 6                interconnected waterways/basins/seas
# 7                         to be determined by experts
# 8          agriculture (including biofuel feedstocks)
# 9                           aquaculture / mariculture
# 10  forestry (including afforestation or reforesta...
# 11                                          fur farms
# 12                                       horticulture
# 13                            live food and live bait
# 14         ornamental purpose other than horticulture
# 15  pet/aquarium/terrarium species (including live...
# 16                        to be determined by experts
# 17                                 biological control
# 18       fishery in the wild (including game fishing)
# 19                        to be determined by experts
# 20                                                NaN
# 21                          angling/fishing equipment
# 22                           other means of transport
# 23  people and their luggage/equipment (in particu...
# 24                            ship/boat ballast water
# 25                        to be determined by experts
# 26                                                NaN
# 27  natural dispersal across borders of invasive a...
# 28                                                NaN

# %%
species_category = unique_species.groupby("category").agg({"count_species_key":sum})
species_category.plot(kind="barh", logx=False)
plt.savefig("category_count.png")

# %%
viz_prep.plot(kind="barh", figsize=(12,12))

# %%
viz_prep.head()
